# %% [markdown]
# # 2D Projectile Motion With Quadratic Drag.
# #### This project simulates the motion of a projectile with quadratic drag in 2D space where the use can adjust initial conditions.

# %% [markdown]
# We can derive the kinematics equations by starting with the definition of average acceleration and average velocity.
# $$ \bar{a} = \frac{\Delta v}{\Delta t} = \frac{v_2 - v_1}{t_2 - t_1} \;\text{and}\; \bar{v} = \frac{\Delta x}{\Delta t} = \frac{x_2 - x_1}{t_2 - t_1} $$
# We set our initial time $ t_1 $ to be 0 and our $ t_2 $ becomes $ t $, so ${\Delta t} = (t_2 - t_1) = (t_2 - 0) = t_2 = t$.
#
# Substituting this into the definition of average acceleration, we get the following: $a = \frac{v - v_0}{t}$ Now, if we solve for $v$, we can get our first kinematics equation:
#
# \begin{aligned}
# (1)\quad & \boxed{v = v_0 + at}
# \end{aligned}
#
#
# By applying the same process to the definition of average velocity ($\bar{v} = \frac{1}{2}v_0+v$), we can get the second kinematics equation: $\bar{v} = \frac{\Delta x}{t} \rightarrow \Delta{x} = \bar{v}t \rightarrow$.
#
# \begin{aligned}
# (2)\quad & \boxed{\Delta{x} = \frac{1}{2}(v_0+v)t}
# \end{aligned}
#
# Next, substituting the expression for $v$ from the first kinematics equation into the second, we can get our third kinematics equation.
#
# \begin{aligned}
# (3)\quad & \boxed{\Delta{x} = v_0t + \frac{1}{2}at^2}
# \end{aligned}
#
# Finally, if we take our equation (1), solve for $t$, and substitute this $t$ into our equation (2) and solve for $v^2$, we obtain the fourth kinematics equation.
#
# \begin{aligned}
# (4)\quad & \boxed{v^2 = v_0^2 + 2a\Delta{x}}
# \end{aligned}
#
# Although these equations describe constant-acceleration motion, our simulation uses numerical integration because drag makes acceleration velocity-dependent. However, there is still one more thing that we need to consider and that is drag. There are three "classical" forms of drag. (Note: There are more forms of drag that range from spinning projectiles to wind-relative, but to keep things short, I'll cover just the three).
#
# <div style="display:flex; justify-content:center; gap:1.5rem; font-size:0.9rem;">
#   <div style="display:flex; align-items:center; gap:0.4rem;">
#     <span>(1) Linear: </span>
#     \({F_d = -bv}\)
#   </div>
#
#   <div style="display:flex; align-items:center; gap:0.4rem;">
#     <span>(2) Quadratic:</span>
#     \({F_d = -cv^2}\)
#   </div>
#
#   <div style="display:flex; align-items:center; gap:0.4rem;">
#     <span>(3) Mixed: </span>
#     \({F_d = -bv - cv^2}\)
#   </div>
# </div>
#
# <div style="margin-top:1rem;">
#
# <p>A linear drag model is best when the projectile is moving slowly and the air (or other medium) flows smoothly around it. In this example, the object is small compared to the medium and viscous effects dominate.
#
# <p>A quadratic drag model is most accurate when the projectile is larger, moving fast, and the flow around it becomes turbulent. This is the case for most sports balls, arrows, and bullets, etc.
#
# <p>A mixed drag model applies when the projectile moves through speeds where neither linear nor quadratic drag dominates for the entire flight,it is typically when it starts fast but slows enough to enter a smoother‑flow regime.</div>
#
# For projectile motion through air, we will use the quadratic drag model. A baseball is large compared to air molecules and travels fast enough that turbulent flow dominates. With this in mind, the net force on the baseball becomes: $$\boxed{\sum\vec{F} = m\vec{g} - c{v^2}{\hat{v}}}$$
#
# This equation says that the sum of forces on our object is equal to its mass (m), gravitational acceleration (g), minus the drag constant of our object multiplied by its velocity squared and the velocity unit vector.
#
# We can break up the net force of our object into its x and y components for the projectile's acceleration, using the velocity unit vector, $\hat{v} = \frac{\vec{v}}{||v||}$, where $||v|| = \sqrt{v_x^2 + v_y^2} = v$. Plugging our new velocities into the equation for the forces on our projectile, we end up with both the x and y components of the projectile's acceleration:
#
# \begin{aligned}
# \; & \boxed{a_x = -\frac{c}{m} v v_x}
# \quad \text{and} \quad
# \; \boxed{a_y = g_y - \frac{c}{m} v v_y}
# \end{aligned}
#
# Lastly, the value of $c$ that we are using is the lumped drag constant which comes from the formula: $$ \boxed{c = \frac{1}{2} \rho C_d A}  $$
#
# Here, $\rho$ is the density of the medium (air in this case), $C_d$ is the drag coefficient (shape dependent), $A$ is the cross-sectional area of the object. You can use the above formula to calculate c for various objects. The initial parameters I have set are for a baseball (c ~ 0.00086).
#
# Now that the theoretical has been covered, we can model our projectiles to determine its behavior, both with and without drag.

# %%
import numpy as np
import matplotlib.pyplot as plt

def kinematics(v_0=30, angle=45, m=0.15, c=0.00086, y0=10.0):
    g = 9.81 # Acceleration due to Earth's gravity.
    dt = 0.001 # Timestep used to simulate projectile.
    theta = np.radians(angle) # Converting used angles from radians to degrees.

    # Initial Conditions for Projectile with Drag.
    vx = v_0 * np.cos(theta)
    vy = v_0 * np.sin(theta)
    x = 0.0 
    y = y0 

    # Initial Conditions for Projectile without Drag.
    vx_nd = vx
    vy_nd = vy
    x_nd = 0.0
    y_nd = y0

    # Stores the points on trajectory
    x_t, y_t = [x], [y]
    x_t_nd, y_t_nd = [x_nd], [y_nd]
    
    t = 0.0
    while (y >= 0 or y_nd >=0) and t < 30:

        if y >= 0:
            v = np.sqrt(vx**2 + vy**2)
            if v > 0:
                # Quadratic drag acceleration: - (c/m) * |v| * v_vector
                ax = -(c/m) * v * vx # X-component of our acceleration which we derived from above.
                ay = -g - (c/m) * v * vy # Y-component of our acceleration which we derived from above.
            else:
                ax = 0
                ay = -g
        
            # Euler Time Step, updates only while the projectile is above ground.
            vx += ax * dt
            vy += ay * dt
            x += vx * dt
            y += vy * dt

            #Stores data while the projectile is above ground.
            x_t.append(x)
            y_t.append(y)

        if y_nd >= 0:
            # Calculations without Drag.
            ax_nd = 0
            ay_nd = -g

            vx_nd += ax_nd * dt
            vy_nd += ay_nd * dt
            x_nd += vx_nd * dt
            y_nd += vy_nd * dt

            x_t_nd.append(x_nd)
            y_t_nd.append(y_nd)
            
        t += dt
        
    # Plots the motion of our projectile.
    plt.figure(figsize=(7, 4))
    plt.plot(x_t, y_t, 'b-', label='With drag')
    plt.plot(x_t_nd, y_t_nd, 'r--', label='No drag')
    plt.xlabel("x (meters)")
    plt.ylabel("y (meters)")
    plt.title(f"Projectile Motion with Quadratic Drag\n"
              f"v₀={v_0} m/s, θ={angle}°, m={m} kg, c={c}")
    plt.grid(True)
    plt.legend()
    plt.show()  
    return None

# %%
from ipywidgets import interact, FloatSlider

interact(
    kinematics,
    v_0=FloatSlider(min=0, max=1000, step=1, value=30, description='v₀ (m/s)'),
    angle=FloatSlider(min=0, max=90, step=1, value=45, description='Angle (°)'),
    m=FloatSlider(min=0.01, max=10, step=0.01, value=0.15, description='Mass (kg)'),
    c=FloatSlider(min=0.00000, max=0.01, step=0.0001, value=0.00086, readout_format='.6f', description='c'),
    y0=FloatSlider(min=0, max=100, step=1, value=10, description='Initial y (m)')
)
# Out:
# interactive(children=(FloatSlider(value=30.0, description='v₀ (m/s)', max=1000.0, step=1.0), FloatSlider(value…
# <function __main__.kinematics(v_0=30, angle=45, m=0.15, c=0.00086, y0=10.0)>
